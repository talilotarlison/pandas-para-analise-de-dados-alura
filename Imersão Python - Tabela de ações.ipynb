# %% [markdown]
# Imersão Python - Tabela de ações

# %%
# importe do pandas
import pandas as pd
import plotly.express as px

# para importar um bibloteca que não esta instala.
# para instalar um biblioteca use o -> !pip install nome_biblioteca.

# %% [markdown]
# # Analise de dados com a planilha do execel

# %%
# importe tabela principal
df_principal = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Principal")
df_principal.head(20)
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5   PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6   PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7   VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8   MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9   ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
# 10  RDOR3 2024-01-26        27.56          1.43           3.41         -4.17
# 11  BRKM5 2024-01-26        18.55          1.42           5.10        -15.14
# 12  AZUL4 2024-01-26        14.27          1.42           8.85        -10.87
# 13  RRRP3 2024-01-26        28.75          1.41          -2.71          9.40
# 14  EQTL3 2024-01-26        35.32          1.34           2.76         -1.12
# 15  CSNA3 2024-01-26        18.16          1.33           4.79         -7.63
# 16  YDUQ3 2024-01-26        19.77          1.28          -5.90        -11.82
# 17  UGPA3 2024-01-26        28.31          1.28           2.35          6.79
# 18  MRVE3 2024-01-26         8.08          1.25           1.38        -28.05
# 19  ARZZ3 2024-01-26        57.91          1.15          -1.03        -10.26
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação %  \
# 0           2.26         15.97      9.18      9.56  319,16 M        0.05
# 1         -12.11         50.56      6.66      6.86   32,65 M        0.02
# 2           7.64         77.55     40.81     42.34  436,69 M        0.02
# 3          -4.89         18.85     51.89     53.17  162,55 M        0.02
# 4          -3.66         20.70     36.37     37.32   73,42 M        0.02
# 5          -0.78          8.08     44.25     45.69  319,92 M        0.02
# 6           7.30         95.01     38.91     40.09    1,64 B        0.02
# 7          -9.97        -23.49     67.50     69.81    1,89 B        0.02
# 8          -0.81         24.02     27.71     28.36  104,16 M        0.02
# 9          -3.36         34.25     32.35     32.91   473,2 M        0.01
# 10         -4.17         -6.01     26.90     27.91   71,62 M        0.01
# 11        -15.14        -18.39     18.29     18.73   43,31 M        0.01
# 12        -10.87         18.52     13.80     14.36  270,24 M        0.01
# 13          9.40        -37.70     28.00     28.75   78,44 M        0.01
# 14         -1.12         28.01     34.85     35.76  412,31 M        0.01
# 15         -7.63         12.45     18.00     18.49  109,86 M        0.01
# 16        -11.82        108.45     18.99     19.78   63,48 M        0.01
# 17          6.79        119.82     27.84     28.39  104,52 M        0.01
# 18        -28.05         14.12      7.93      8.23  109,48 M        0.01
# 19        -10.26        -28.97     56.22     59.29  202,83 M        0.01
#
#     Valor inical (R$)  Quntidade de ações    Variação $ Resultado  \
# 0                9.03           515117391  241889725.40     Subiu
# 1                6.66          1110559345  177515970.30     Subiu
# 2               41.06          2379877655 2140059394.00     Subiu
# 3               51.85           683452836  722946282.70     Subiu
# 4               36.36           187732538  138573955.10     Subiu
# 5               44.80           800010734  709687498.20     Subiu
# 6               39.28          4566445852 3103136291.00     Subiu
# 7               68.37          4196924316 4762926995.00     Subiu
# 8               27.75           268505432  117732680.10     Subiu
# 9               32.33          4801593832 2297591984.00     Subiu
# 10              27.17          1168230366  453917907.00     Subiu
# 11              18.29           265877867   69054317.64     Subiu
# 12              14.07           327593725   65452205.55     Subiu
# 13              28.35           235665566   94204643.35     Subiu
# 14              34.85          1095587251  511671895.50     Subiu
# 15              17.92           600865451  143220991.50     Subiu
# 16              19.52           289347914   72295838.99     Subiu
# 17              27.95          1086411192  388705224.00     Subiu
# 18               7.98           376187582   37525872.38     Subiu
# 19              57.25            62305891   41021792.09     Subiu
#
#          Nome da empresa              Segmento  Idade         Cat. Idade
# 0               Usiminas            Siderurgia     60     Entre 50 e 100
# 1          CSN Mineração             Mineração     80     Entre 50 e 100
# 2              Petrobras    Energia e Petróleo     68     Entre 50 e 100
# 3                 Suzano      Papel e Celulose     99     Entre 50 e 100
# 4           CPFL Energia      Energia Elétrica    108   Mais de 100 anos
# 5               PetroRio        Petróleo e Gás     10  Menos que 50 anos
# 6              Petrobras    Energia e Petróleo     68     Entre 50 e 100
# 7                   Vale             Mineração     80     Entre 50 e 100
# 8              Multiplan      Shopping Centers     48  Menos que 50 anos
# 9          Itaú Unibanco  Serviços Financeiros     97     Entre 50 e 100
# 10             Rede D'Or                 Saúde     45  Menos que 50 anos
# 11               Braskem               Química     19  Menos que 50 anos
# 12                  Azul      Transporte Aéreo     14  Menos que 50 anos
# 13          3R Petroleum        Petróleo e Gás      4  Menos que 50 anos
# 14    Equatorial Energia      Energia Elétrica     22  Menos que 50 anos
# 15  Siderúrgica Nacional            Siderurgia     80     Entre 50 e 100
# 16                 YDUQS              Educação     53     Entre 50 e 100
# 17              Ultrapar          Distribuição     84     Entre 50 e 100
# 18                   MRV      Construção Civil     42  Menos que 50 anos
# 19                Arezzo        Varejo de Moda     50     Entre 50 e 100

# %%
# importe tabela total de açoes
df_total_acoes = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Total_de_acoes")
df_total_acoes.head(20)
# Out:
#     Código  Qtde. Teórica
# 0    RRRP3   235665566.00
# 1    ALOS3   532616595.00
# 2    ALPA4   176733968.00
# 3    ABEV3  4394245879.00
# 4    ARZZ3    62305891.00
# 5    ASAI3  1349217892.00
# 6    AZUL4   327593725.00
# 7    B3SA3  5602790110.00
# 8    BBSE3   671750768.00
# 9    BBDC3  1500728902.00
# 10   BBDC4  5146576868.00
# 11   BRAP4   251003438.00
# 12   BBAS3  1420949112.00
# 13   BRKM5   265877867.00
# 14   BRFS3  1677525446.00
# 15  BPAC11  1150645866.00
# 16   CRFB3   533990587.00
# 17   BHIA3    94843047.00
# 18   CCRO3   995335937.00
# 19   CMIG4  1437415777.00

# %%
df_ticker = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/acoes_pura.xlsx", sheet_name="ChatGpt")
df_chatgpt
# Out:
#      Nome da Empresa Segmento de Atuação  Idade Aproximada (Anos)  \
# 0           Usiminas          Siderurgia                       60
# 1      CSN Mineração           Mineração                       80
# 2          Petrobras  Energia e Petróleo                       68
# 3             Suzano    Papel e Celulose                       99
# 4       CPFL Energia    Energia Elétrica                      108
# ..               ...                 ...                      ...
# 74  Carrefour Brasil  Varejo Alimentício                       46
# 75       Casas Bahia              Varejo                       68
# 76          Localiza   Aluguel de Carros                       48
# 77               CVC   Turismo e Viagens                       49
# 78               GOL     Companhia Aérea                       20
#
#                                         Notas com GPT
# 0   The SheetGPT service experienced an unrecogniz...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
# [79 rows x 4 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final', 'Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['valor_inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal = df_principal.drop(columns=['Nome da Empresa','Notas com GPT'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome  \
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
#    Segmento de Atuação  Idade Aproximada (Anos)
# 0           Siderurgia                       60
# 1            Mineração                       80
# 2   Energia e Petróleo                       68
# 3     Papel e Celulose                       99
# 4     Energia Elétrica                      108
# ..                 ...                      ...
# 76  Varejo Alimentício                       46
# 77              Varejo                       68
# 78   Aluguel de Carros                       48
# 79   Turismo e Viagens                       49
# 80     Companhia Aérea                       20
#
# [81 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade Aproximada (Anos)':'Idade'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome  \
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
#    Segmento de Atuação  Idade
# 0           Siderurgia     60
# 1            Mineração     80
# 2   Energia e Petróleo     68
# 3     Papel e Celulose     99
# 4     Energia Elétrica    108
# ..                 ...    ...
# 76  Varejo Alimentício     46
# 77              Varejo     68
# 78   Aluguel de Carros     48
# 79   Turismo e Viagens     49
# 80     Companhia Aérea     20
#
# [81 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade':'Ano_de_fundacao'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome  \
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
#    Segmento de Atuação  Ano_de_fundacao
# 0           Siderurgia               60
# 1            Mineração               80
# 2   Energia e Petróleo               68
# 3     Papel e Celulose               99
# 4     Energia Elétrica              108
# ..                 ...              ...
# 76  Varejo Alimentício               46
# 77              Varejo               68
# 78   Aluguel de Carros               48
# 79   Turismo e Viagens               49
# 80     Companhia Aérea               20
#
# [81 rows x 12 columns]

# %%
df_principal['Cat_idade'] = df_principal['Ano_de_fundacao'].apply(lambda x: 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome  \
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
#    Segmento de Atuação  Ano_de_fundacao       Cat_idade
# 0           Siderurgia               60  Entre 50 e 100
# 1            Mineração               80  Entre 50 e 100
# 2   Energia e Petróleo               68  Entre 50 e 100
# 3     Papel e Celulose               99  Entre 50 e 100
# 4     Energia Elétrica              108     Mais de 100
# ..                 ...              ...             ...
# 76  Varejo Alimentício               46     Menos de 50
# 77              Varejo               68  Entre 50 e 100
# 78   Aluguel de Carros               48     Menos de 50
# 79   Turismo e Viagens               49     Menos de 50
# 80     Companhia Aérea               20     Menos de 50
#
# [81 rows x 13 columns]

# %%
df_principal = df_principal.rename(columns={'Segmento de Atuação':'Segmento'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado              Nome  \
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
#               Segmento  Ano_de_fundacao       Cat_idade
# 0           Siderurgia               60  Entre 50 e 100
# 1            Mineração               80  Entre 50 e 100
# 2   Energia e Petróleo               68  Entre 50 e 100
# 3     Papel e Celulose               99  Entre 50 e 100
# 4     Energia Elétrica              108     Mais de 100
# ..                 ...              ...             ...
# 76  Varejo Alimentício               46     Menos de 50
# 77              Varejo               68  Entre 50 e 100
# 78   Aluguel de Carros               48     Menos de 50
# 79   Turismo e Viagens               49     Menos de 50
# 80     Companhia Aérea               20     Menos de 50
#
# [81 rows x 13 columns]

# %%
# Calculando o maior valor
maior = df_principal['Variacao_rs'].max()

# Calculando o menor valor
menor = df_principal['Variacao_rs'].min()

# Calculando a média
media = df_principal['Variacao_rs'].mean()

# Calculando a média de quem subiu
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()

# Calculando a média de quem desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

# Imprimindo os resultados
print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.25
# Menor	R$ -1,807,432,634.46
# Média	R$ 165,190,210.48
# Média de quem subiu	R$ 448,164,250.23
# Média de quem desceu	R$ -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8   MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9   ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 10  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 11  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 12  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 13  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 14  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 15  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 16  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 17  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 18  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 19  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 20  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 21  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 22  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 23  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 24  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 25  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 26  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 27  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 28  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 29  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 30  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 31  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 32  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 33  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 34  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 35  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 36  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 37  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 38  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 39  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 40  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 41  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 42  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 43  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     Qtd_teorica   Variacao_rs Resultado                  Nome  \
# 0     515117391  241889725.43     Subiu              Usiminas
# 1    1110559345  177515970.30     Subiu         CSN Mineração
# 2    2379877655 2140059393.53     Subiu             Petrobras
# 3     683452836  722946282.71     Subiu                Suzano
# 4     187732538  138573955.06     Subiu          CPFL Energia
# 5     800010734  709687498.18     Subiu              PetroRio
# 6    4566445852 3103136291.22     Subiu             Petrobras
# 7    4196924316 4762926995.25     Subiu                  Vale
# 8     268505432  117732680.08     Subiu             Multiplan
# 9    4801593832 2297591984.33     Subiu         Itaú Unibanco
# 10   1168230366  453917907.01     Subiu             Rede D'Or
# 11    265877867   69054317.64     Subiu               Braskem
# 12    327593725   65452205.55     Subiu                  Azul
# 13    235665566   94204643.35     Subiu          3R Petroleum
# 14   1095587251  511671895.45     Subiu    Equatorial Energia
# 15    600865451  143220991.46     Subiu  Siderúrgica Nacional
# 16    289347914   72295838.99     Subiu                 YDUQS
# 17   1086411192  388705223.96     Subiu              Ultrapar
# 18    376187582   37525872.38     Subiu                   MRV
# 19     62305891   41021792.09     Subiu                Arezzo
# 20   5146576868  822148336.41     Subiu        Banco Bradesco
# 21    261036182   18214628.10     Subiu               Minerva
# 22    159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 23   1677525446  233045769.57     Subiu                   BRF
# 24    423091712  188965307.06     Subiu                  Vivo
# 25   1218352541  229771333.63     Subiu                  Rumo
# 26   1095462329   43657683.38     Subiu                 Cielo
# 27    302768240   18068446.61     Subiu                 Dexco
# 28    807896814  103972807.37     Subiu                   TIM
# 29    251003438   42238249.54     Subiu             Bradespar
# 30    393173139   15598886.65     Subiu               Locaweb
# 31    275005663   46201006.00     Subiu        PetroRecôncavo
# 32   5372783971  373853994.88     Subiu                Itaúsa
# 33   1420949112  546752087.99     Subiu       Banco do Brasil
# 34   1275798515  202352473.74     Subiu          RaiaDrogasil
# 35    660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 36   1168097881  127229653.18     Subiu                 Cosan
# 37   1134986472  156573285.43     Subiu                   JBS
# 38   2867627068   28493619.27     Subiu        Magazine Luiza
# 39   1500728902   74019610.05     Subiu        Banco Bradesco
# 40   1118525506   65779607.10     Subiu                Gerdau
# 41   1193047233   11571106.42     Subiu                Raízen
# 42   1679335290   32069789.50     Subiu                 Copel
# 43    421383330    4131341.16     Subiu           Grupo Vamos
#
#                 Segmento  Ano_de_fundacao       Cat_idade
# 0             Siderurgia               60  Entre 50 e 100
# 1              Mineração               80  Entre 50 e 100
# 2     Energia e Petróleo               68  Entre 50 e 100
# 3       Papel e Celulose               99  Entre 50 e 100
# 4       Energia Elétrica              108     Mais de 100
# 5         Petróleo e Gás               10     Menos de 50
# 6     Energia e Petróleo               68  Entre 50 e 100
# 7              Mineração               80  Entre 50 e 100
# 8       Shopping Centers               48     Menos de 50
# 9   Serviços Financeiros               97  Entre 50 e 100
# 10                 Saúde               45     Menos de 50
# 11               Química               19     Menos de 50
# 12      Transporte Aéreo               14     Menos de 50
# 13        Petróleo e Gás                4     Menos de 50
# 14      Energia Elétrica               22     Menos de 50
# 15            Siderurgia               80  Entre 50 e 100
# 16              Educação               53  Entre 50 e 100
# 17          Distribuição               84  Entre 50 e 100
# 18      Construção Civil               42     Menos de 50
# 19        Varejo de Moda               50  Entre 50 e 100
# 20  Serviços Financeiros               79  Entre 50 e 100
# 21             Alimentos               30     Menos de 50
# 22                Varejo               72  Entre 50 e 100
# 23             Alimentos               84  Entre 50 e 100
# 24      Telecomunicações               23     Menos de 50
# 25             Logística               13     Menos de 50
# 26    Meios de Pagamento               23     Menos de 50
# 27            Tecnologia                7     Menos de 50
# 28      Telecomunicações               26     Menos de 50
# 29         Investimentos               20     Menos de 50
# 30            Tecnologia               24     Menos de 50
# 31        Petróleo e Gás                5     Menos de 50
# 32         Investimentos               56  Entre 50 e 100
# 33  Serviços Financeiros              213     Mais de 100
# 34   Varejo Farmacêutico              116     Mais de 100
# 35            Siderurgia              120     Mais de 100
# 36   Energia e Logística               24     Menos de 50
# 37             Alimentos               68  Entre 50 e 100
# 38                Varejo               64  Entre 50 e 100
# 39  Serviços Financeiros               79  Entre 50 e 100
# 40            Siderurgia              120     Mais de 100
# 41   Energia e Logística                9     Menos de 50
# 42      Energia Elétrica               66  Entre 50 e 100
# 43             Logística                6     Menos de 50

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#                 Segmento   Variacao_rs
# 0              Alimentos  407833683.09
# 1       Construção Civil   37525872.38
# 2           Distribuição  388705223.96
# 3               Educação   72295838.99
# 4       Energia Elétrica  682315640.01
# 5    Energia e Logística  138800759.60
# 6     Energia e Petróleo 5243195684.74
# 7          Investimentos  416092244.42
# 8              Logística  233902674.79
# 9     Meios de Pagamento   43657683.38
# 10             Mineração 4940442965.55
# 11      Papel e Celulose  722946282.71
# 12        Petróleo e Gás  850093147.52
# 13               Química   69054317.64
# 14                 Saúde  453917907.01
# 15  Serviços Financeiros 3740512018.78
# 16      Shopping Centers  117732680.08
# 17            Siderurgia  489935930.93
# 18            Tecnologia   33667333.26
# 19      Telecomunicações  292938114.42
# 20      Transporte Aéreo   65452205.55
# 21                Varejo   34834535.50
# 22   Varejo Farmacêutico  202352473.74
# 23        Varejo de Moda   41021792.09

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 19719227010.14

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="80bef360-c1be-407e-b0ff-fb4667b452a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80bef360-c1be-407e-b0ff-fb4667b452a1")) {                    Plotly.newPlot(                        "80bef360-c1be-407e-b0ff-fb4667b452a1",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6338819961.31535,0.0,19719227010.14191],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6338819961.31535,0.0,19719227010.14191],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}] ...
