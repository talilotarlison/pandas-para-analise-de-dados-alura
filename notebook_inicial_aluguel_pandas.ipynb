# %% [markdown]
# # Conhecendo a base de dados

# %% [markdown]
# ## Importando os dados

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
pd.read_csv(url, sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados = pd.read_csv(url, sep=';')
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
dados.tail(10)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32950    28   1000.0       360.0    25.0
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
display(dados.describe())
display(dados.dtypes)
display(dados.columns)
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %% [markdown]
# ## Características gerais da base de dados

# %%
dados['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados[['Quartos', 'Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# # Análise exploratória de dados

# %% [markdown]
# ## Qual o valor médio de aluguel por tipo de imóvel?

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor'].mean()
# Out:
# np.float64(12952.659715265761)

# %%
dados.groupby('Tipo').mean(numeric_only=True)
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
dados.groupby('Tipo')['Valor'].mean(numeric_only=True)
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
dados.groupby('Tipo')['Valor'].mean(numeric_only=True).sort_values(ascending=False)
# Out:
# Tipo
# Prédio Inteiro                 498637.239203
# Indústria                      120000.000000
# Galpão/Depósito/Armazém         53407.062600
# Terreno Padrão                  32567.714286
# Hotel                           25000.000000
# Loteamento/Condomínio           22000.000000
# Conjunto Comercial/Sala         14715.045521
# Casa Comercial                  14478.264151
# Loja/Salão                      13769.646770
# Sítio                           12499.000000
# Casa de Condomínio              11952.061245
# Loja Shopping/ Ct Comercial      8126.178862
# Casa                             6793.454922
# Chácara                          4900.000000
# Apartamento                      4744.614648
# Flat                             4546.189076
# Loft                             2557.882353
# Studio                           2400.000000
# Box/Garagem                      1899.756098
# Casa de Vila                     1574.369478
# Pousada/Chalé                    1480.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

avg_valor_por_tipo = dados.groupby('Tipo')['Valor'].mean(numeric_only=True).sort_values(ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x=avg_valor_por_tipo.index, y=avg_valor_por_tipo.values, palette='viridis')
plt.title('Valor Médio de Aluguel por Tipo de Imóvel')
plt.xlabel('Tipo de Imóvel')
plt.ylabel('Valor Médio de Aluguel')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2485576366.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_valor_por_tipo.index, y=avg_valor_por_tipo.values, palette='viridis')

# %%
df_preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple');

# %% [markdown]
# ## Removendo os imóveis comerciais

# %%
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']
dados.query('Tipo in @imoveis_comerciais')
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
# dados.query('Tipo not in @imoveis_comerciais')

df = dados.query('@imoveis_comerciais not in Tipo')
df.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preco_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple');

# %% [markdown]
# ## Qual o percentual de cada tipo de imóvel na nossa base de dados?

# %%
df_preco_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_preco_tipo
# Out:
#                            Valor
# Tipo
# Quitinete            1246.840909
# Casa de Vila         1574.369478
# Studio               2400.000000
# Loft                 2557.882353
# Flat                 4546.189076
# Apartamento          4744.614648
# Casa                 6793.454922
# Casa de Condomínio  11952.061245

# %%
df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple');

# %%
percentual_tipo = df['Tipo'].value_counts(normalize=True) * 100
percentual_tipo = percentual_tipo.to_frame('Percentual').rename_axis('Tipo')
display(percentual_tipo)
# Out:
#                     Percentual
# Tipo
# Apartamento          84.513868
# Casa de Condomínio    4.309636
# Casa                  4.184155
# Quitinete             3.617325
# Flat                  2.059625
# Casa de Vila          1.077409
# Loft                  0.220674
# Studio                0.017308

# %% [markdown]
# O gráfico a seguir representa o percentual de cada tipo de imóvel, o que ajuda a visualizar a proporção de cada categoria no seu conjunto de dados.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=percentual_tipo.index, y=percentual_tipo['Percentual'], palette='viridis')
plt.title('Percentual de Cada Tipo de Imóvel')
plt.xlabel('Tipo de Imóvel')
plt.ylabel('Percentual (%)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3816639008.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=percentual_tipo.index, y=percentual_tipo['Percentual'], palette='viridis')

# %%
percentual_tipo = df['Tipo'].value_counts(normalize=True) * 100
percentual_tipo = percentual_tipo.to_frame('Percentual').rename_axis('Tipo')
display(percentual_tipo)
# Out:
#                     Percentual
# Tipo
# Apartamento          84.513868
# Casa de Condomínio    4.309636
# Casa                  4.184155
# Quitinete             3.617325
# Flat                  2.059625
# Casa de Vila          1.077409
# Loft                  0.220674
# Studio                0.017308

# %%
plt.figure(figsize=(10, 8))
percentual_tipo.plot.pie(y='Percentual', autopct='%1.1f%%', startangle=90, legend=False)
plt.title('Percentual de Cada Tipo de Imóvel')
plt.ylabel('') # Hide y-label for better aesthetics in pie chart
plt.tight_layout()
plt.show()

# %%
df_percentual_tipo = df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo')

df_percentual_tipo.plot(kind='bar', figsize=(14, 10), color ='green',
                        xlabel = 'Tipos', ylabel = 'Percentual');

# %% [markdown]
# ### **Selecionando apenas os imóveis do tipo apartamento**

# %%
df = df.query('Tipo == "Apartamento"')
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# # Tratando e filtrando os dados

# %% [markdown]
# ## Lidando com dados nulos

# %%
dados.isnull().sum()
# Out:
# Tipo              0
# Bairro            0
# Quartos           0
# Vagas             0
# Suites            0
# Area              0
# Valor            17
# Condominio     4093
# IPTU          10237
# dtype: int64

# %%
df['Valor'].isnull().sum()
# Out:
# np.int64(7)

# %%
df['Valor'].isnull()
# Out:
# 3        False
# 4        False
# 5        False
# 6        False
# 10       False
#          ...
# 32951    False
# 32953    False
# 32956    False
# 32957    False
# 32958    False
# Name: Valor, Length: 19532, dtype: bool

# %%
dados.isnull().sum()
# Out:
# Tipo              0
# Bairro            0
# Quartos           0
# Vagas             0
# Suites            0
# Area              0
# Valor            17
# Condominio     4093
# IPTU          10237
# dtype: int64

# %%
dados = pd.read_csv(url, sep=';') # Reload dados to ensure it's not empty
dados = dados.fillna(0)
display(dados.isnull().sum())
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# Tratar dados nulos em uma base de dados é muito importante porque esses dados faltantes podem interferir diretamente na qualidade das análises e nos resultados obtidos. Quando existem dados nulos em um conjunto de dados, podem ocorrer problemas como viés, redução da acurácia e imprecisão nas informações obtidas.
#
# Além disso, algumas análises e modelos estatísticos não são capazes de lidar com a presença de dados faltantes. Por isso, o tratamento dos dados nulos é fundamental para garantir a confiabilidade e a precisão das análises e decisões tomadas a partir desses dados.
#
# Existem diversas formas de tratar dados nulos com o Pandas. Algumas das principais formas são:
#
# Remover os dados nulos: É possível remover as linhas ou colunas que possuem valores nulos utilizando o método dropna() . Esse método remove todas as linhas ou colunas que possuem pelo menos um valor nulo.
#
# Preencher os dados nulos: Utilizando o método fillna(), podemos preencher os valores nulos com um valor específico. Além disso, também é possível utilizar argumentos específicos do método fillna() como o method=”ffill” ou method=”bfill” para preencher os valores nulos com o valor anterior ou posterior, respectivamente.
#
# Interpolar os dados nulos: É possível utilizar o método interpolate() para preencher os valores nulos com valores interpolados, ou seja, valores calculados a partir dos valores vizinhos.

# %% [markdown]
# ## Removendo registros

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         0.0     0.0
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     0.0

# %%
# Para remover apartamentos com valor igual a 0 ou condomínio igual a 0, filtramos para manter os que NÃO tem Valor=0 e NÃO tem Condominio=0
dados = dados.query('Valor != 0 and Condominio != 0')
display(dados.head())
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 6              Apartamento         Cachambi        2      0       0    50
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     0.0
# 6  1300.0       301.0    17.0

# %%
# Este passo não é mais necessário, pois o filtro já foi aplicado na célula anterior.
registro_remover = dados.query('Valor == 0 | Condominio == 0').index
registro_remover
# Out:
# Index([], dtype='int64')

# %%
dados.query('Valor == 0 | Condominio == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.head(20)
# Out:
#            Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 3   Apartamento                   Centro        1      0       0    15
# 4   Apartamento             Higienópolis        1      0       0    48
# 5   Apartamento             Vista Alegre        3      1       0    70
# 6   Apartamento                 Cachambi        2      0       0    50
# 10  Apartamento                   Centro        1      0       0    36
# 11  Apartamento                   Grajaú        2      1       0    70
# 12  Apartamento      Lins de Vasconcelos        3      1       1    90
# 13  Apartamento               Copacabana        1      0       1    40
# 15  Apartamento               Copacabana        4      3       1   243
# 19  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
# 20  Apartamento          Barra da Tijuca        2      1       1    67
# 21  Apartamento                   Tijuca        2      1       0   110
# ...

# %%
df.Tipo.unique()
# Out:
# array(['Apartamento'], dtype=object)

# %%
df.drop('Tipo', axis= 1,inplace=True)

# %%
df.head()
# Out:
#           Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  IPTU
# 3         Centro        1      0       0    15   800.0       390.0  20.0
# 4   Higienópolis        1      0       0    48   800.0       230.0   NaN
# 5   Vista Alegre        3      1       0    70  1200.0         NaN   NaN
# 6       Cachambi        2      0       0    50  1300.0       301.0  17.0
# 10        Centro        1      0       0    36  1200.0         NaN   NaN

# %% [markdown]
# ## Filtros

# %% [markdown]
# ### **1. Apartamentos que possuem `1 quarto` e `aluguel menor que 1200`**

# %%
df.query('Quartos == 1 and Valor < 1200')
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    NaN
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32643     Guadalupe        1      0       0    40   550.0         NaN    NaN
# 32666    Bonsucesso        1      0       0    60  1000.0         NaN    NaN
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [623 rows x 8 columns]

# %% [markdown]
# ### **2. `Apartamentos` que possuem pelo menos `2 quartos`, `aluguel menor que 3000` e `area maior que 70`**

# %%
df.query('Quartos >= 2 and Valor < 3000 and Area > 70')
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 12          Lins de Vasconcelos        3      1       1    90  1500.0
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 36     Recreio dos Bandeirantes        3      1       1   105  2300.0
# ...                         ...      ...    ...     ...   ...     ...
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
# 32941           Barra da Tijuca        3      2       0    98  2300.0
# 32944  Recreio dos Bandeirantes        3      2       1    88  1550.0
# 32956               Jacarepaguá        3      1       2    78  1800.0
#
#        Condominio   IPTU
# 12          455.0   14.0
# 21          700.0  138.0
# 24          700.0    NaN
# ...

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
# Empty DataFrame
# Columns: [Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ## Salvando os dados

# %%
df.to_csv('dados_tratados.csv', index=False)

# %%
pd.read_csv('dados_tratados.csv')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2              Vista Alegre        3      1       0    70  1200.0         NaN
# 3                  Cachambi        2      0       0    50  1300.0       301.0
# 4                    Centro        1      0       0    36  1200.0         NaN
# ...                     ...      ...    ...     ...   ...     ...         ...
# 19527        Vila Valqueire        2      0       0    52  1000.0       550.0
# 19528                 Méier        2      0       0    70   900.0       490.0
# 19529           Jacarepaguá        3      1       2    78  1800.0       800.0
# 19530  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 19531                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %%
df.to_csv('dados_tratados.csv', index=False, sep=';')

# %%
pd.read_csv('dados_tratados.csv', sep=';')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2              Vista Alegre        3      1       0    70  1200.0         NaN
# 3                  Cachambi        2      0       0    50  1300.0       301.0
# 4                    Centro        1      0       0    36  1200.0         NaN
# ...                     ...      ...    ...     ...   ...     ...         ...
# 19527        Vila Valqueire        2      0       0    52  1000.0       550.0
# 19528                 Méier        2      0       0    70   900.0       490.0
# 19529           Jacarepaguá        3      1       2    78  1800.0       800.0
# 19530  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 19531                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %%
# O Pandas oferece diversos métodos para salvar arquivos em diferentes formatos. Alguns exemplos são:

# to_csv(): salva o DataFrame em um arquivo CSV (Comma-Separated Values);

# to_excel(): salva o DataFrame em um arquivo Excel;

# to_json(): salva o DataFrame em um arquivo JSON (JavaScript Object Notation).

# Esses são apenas alguns exemplos, existem outros métodos disponíveis no Pandas para salvar arquivos em diferentes formatos. Caso queira conhecê-los, acesse a documentação:

# %% [markdown]
# O Pandas oferece diversos métodos para salvar arquivos em diferentes formatos. Alguns exemplos são:
#
# to_csv(): salva o DataFrame em um arquivo CSV (Comma-Separated Values);
#
# to_excel(): salva o DataFrame em um arquivo Excel;
#
# to_json(): salva o DataFrame em um arquivo JSON (JavaScript Object Notation).
#
# Esses são apenas alguns exemplos, existem outros métodos disponíveis no Pandas para salvar arquivos em diferentes formatos. Caso queira conhecê-los, acesse a documentação:

# %% [markdown]
# # Manipulando os dados

# %% [markdown]
# ## Criando colunas numéricas

# %%
df.head()
# Out:
#           Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  IPTU
# 3         Centro        1      0       0    15   800.0       390.0  20.0
# 4   Higienópolis        1      0       0    48   800.0       230.0   NaN
# 5   Vista Alegre        3      1       0    70  1200.0         NaN   NaN
# 6       Cachambi        2      0       0    50  1300.0       301.0  17.0
# 10        Centro        1      0       0    36  1200.0         NaN   NaN

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
# valor aluguel anual
dados['aluguel_anual'] = dados['Valor'] * 12
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  aluguel_anual
# 0  1700.0       500.0    60.0        20400.0
# 1  7000.0         NaN     NaN        84000.0
# 2  5200.0      4020.0  1111.0        62400.0
# 3   800.0       390.0    20.0         9600.0
# 4   800.0       230.0     NaN         9600.0

# %%
# os gastos mensais de cada imóvel, incluindo aluguel e condomínio;
dados['valor_por_mes'] = dados['Valor'] + dados['Condominio']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  aluguel_anual  valor_por_mes
# 0  1700.0       500.0    60.0        20400.0         2200.0
# 1  7000.0         NaN     NaN        84000.0            NaN
# 2  5200.0      4020.0  1111.0        62400.0         9220.0
# 3   800.0       390.0    20.0         9600.0         1190.0
# 4   800.0       230.0     NaN         9600.0         1030.0

# %%
#essa coluna deve conter os gastos anuais por imóvel, ou seja, IPTU mais 12 meses de aluguel e condomínio.
dados['valor_por_ano'] = dados['aluguel_anual'] + dados['IPTU']
dados.head()
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %% [markdown]
# ## Criando colunas categóricas

# %%
#essa coluna deve possuir uma sumarização das principais informações dos imóveis que serão apresentadas no site: tipo de imóvel, bairro, quantidade de quartos e vagas de garagem;
dados['descricao'] = dados.apply(lambda row: f"O {row['Tipo']} localizado em {row['Bairro']} possui {int(row['Quartos'])} quartos, {int(row['Vagas'])} vagas e custa um aluguel mensal de R$ {row['Valor']:.2f}", axis=1)

# %%
pd.set_option('display.max_colwidth', None)
display(dados.head())
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  aluguel_anual  valor_por_mes  valor_por_ano  \
# 0  1700.0       500.0    60.0        20400.0         2200.0        20460.0
# 1  7000.0         NaN     NaN        84000.0            NaN            NaN
# 2  5200.0      4020.0  1111.0        62400.0         9220.0        63511.0
# 3   800.0       390.0    20.0         9600.0         1190.0         9620.0
# 4   800.0       230.0     NaN         9600.0         1030.0            NaN
#
# ...

# %%
print("\nAlgumas descrições completas:\n")
print(dados['descricao'].head())
# Out:
# Algumas descrições completas:
#
# 0                       O Quitinete localizado em Copacabana possui 1 quartos, 0 vagas e custa um aluguel mensal de R$ 1700.00
# 1                       O Casa localizado em Jardim Botânico possui 2 quartos, 0 vagas e custa um aluguel mensal de R$ 7000.00
# 2    O Conjunto Comercial/Sala localizado em Barra da Tijuca possui 0 quartos, 4 vagas e custa um aluguel mensal de R$ 5200.00
# 3                          O Apartamento localizado em Centro possui 1 quartos, 0 vagas e custa um aluguel mensal de R$ 800.00
# 4                    O Apartamento localizado em Higienópolis possui 1 quartos, 0 vagas e custa um aluguel mensal de R$ 800.00
# Name: descricao, dtype: object

# %%
dados['Possui_suite'] = dados['Suites'].apply(lambda x: "Sim" if x > 0 else "Não")
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  aluguel_anual  valor_por_mes  valor_por_ano  \
# 0  1700.0       500.0    60.0        20400.0         2200.0        20460.0
# 1  7000.0         NaN     NaN        84000.0            NaN            NaN
# 2  5200.0      4020.0  1111.0        62400.0         9220.0        63511.0
# 3   800.0       390.0    20.0         9600.0         1190.0         9620.0
# 4   800.0       230.0     NaN         9600.0         1030.0            NaN
#
# ...

# %%
#Possui_suite: essa deve ser uma coluna que informe apenas se o imóvel possui ou não suítes, sem se importar com a quantidade.
dados['Possui_suite'] = dados['Suites'].apply(lambda x: 1 if x > 0 else 0)
display(dados.head())
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  aluguel_anual  valor_por_mes  valor_por_ano  \
# 0  1700.0       500.0    60.0        20400.0         2200.0        20460.0
# 1  7000.0         NaN     NaN        84000.0            NaN            NaN
# 2  5200.0      4020.0  1111.0        62400.0         9220.0        63511.0
# 3   800.0       390.0    20.0         9600.0         1190.0         9620.0
# 4   800.0       230.0     NaN         9600.0         1030.0            NaN
#
# ...
